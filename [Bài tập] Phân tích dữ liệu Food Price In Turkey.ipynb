# %%
import pandas as pd
data=pd.read_csv('FoodPrice_in_Turkey.csv', encoding="ISO-8859-1")
data.info()
display(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# ...

# %%
#Giá trung bình của từng loại thực phẩm là bao nhiêu
print("Tổng của từng loại thực phẩm")
a= data.groupby('ProductName')['Price'].sum()
b= data.groupby('ProductName')['UmId'].sum()
c=a/b
print(c)
# Out:
# Tổng của từng loại thực phẩm
# ProductName
# Apples (red) - Retail                                      0.478439
# Apples - Retail                                            0.777008
# Bananas - Retail                                           1.644957
# Beans (white) - Retail                                     1.914566
# Bread (common) - Retail                                    0.892659
# Bread (pita) - Retail                                      0.480909
# Bulgur - Retail                                            0.703342
# Cabbage - Retail                                           0.344679
# Cauliflower - Retail                                       0.654974
# Cheese - Retail                                            5.104575
# Chickpeas - Retail                                         2.069572
# Cocoa (powder) - Retail                                    8.760468
# Coffee (instant) - Retail                                  1.311985
# ...
