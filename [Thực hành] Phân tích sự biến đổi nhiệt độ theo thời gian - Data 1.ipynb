# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('daily-min-temperatures.csv')
data
# Out:
#             Date  Temp
# 0     1981-01-01  20.7
# 1     1981-01-02  17.9
# 2     1981-01-03  18.8
# 3     1981-01-04  14.6
# 4     1981-01-05  15.8
# ...          ...   ...
# 3645  1990-12-27  14.0
# 3646  1990-12-28  13.6
# 3647  1990-12-29  13.5
# 3648  1990-12-30  15.7
# 3649  1990-12-31  13.0
#
# [3650 rows x 2 columns]

# %% [markdown]
# # Hiển thị các giá trị thống kê của dữ liệu nhiệt độ

# %%
data['Temp'].describe()
# Out:
# count    3650.000000
# mean       11.177753
# std         4.071837
# min         0.000000
# 25%         8.300000
# 50%        11.000000
# 75%        14.000000
# max        26.300000
# Name: Temp, dtype: float64

# %% [markdown]
# # Vẽ biểu đồ Histogram

# %%
plt.hist(data['Temp'],bins=45)
plt.show()

# %% [markdown]
# # Tinh chỉnh biểu đồ

# %%
plt.hist(data['Temp'],bins=45,range=(1,23),histtype='step')
plt.title('Temperature Histogram', fontsize=16)
plt.show()

# %% [markdown]
# # Vẽ biểu đồ đường thể hiện xu hướng nhiệt độ

# %%
plt.plot(data['Date'],data['Temp'])
plt.title('Daily Temperature')
plt.xlabel('Date',fontsize=14)
plt.ylabel('Temp',fontsize=14)
plt.show()

# %%
#Giá trị xuất hiện nhiều nhất là trong khoảng 10-11 độ.
#Có một số giá trị bất thường ở cả 2 phía. Một số rất ít ngày có nhiệt độ cao bất thường trên 23 độ và thấp bất thường dưới 1 độ.
#Nhìn chung, nếu loại bỏ các ngày có giá trị bất thường, có thể nói nhiệt độ tuân theo phân phối chuẩn.

# %%
#Có thể thay xu hướng thay đổi nhiệt độ có tính chu kỳ.
#Dựa vào đồ thị, ta phán đoán chu kì thay đổi của nhiệt độ là theo năm.
#Tuy nhiên, do khoảng thời gian biểu diễn dài nên khó có thể nhìn chi tiết xu hướng biến đổi nhiệt độ trong năm. Do đó ta vẽ bổ sung biểu đồ đường thể hiện xu hướng nhiệt độ theo từng năm quan tâm.

# %%
data['Date']=pd.to_datetime(data['Date'])
bounds=['01/01/1990','12/31/1990']
bounds=pd.to_datetime(bounds)
d1=data[(data['Date']>= bounds[0])&(data['Date']<=bounds[1])]
plt.plot(d1['Date'],d1['Temp'])
plt.title('Daily Temperature in 1990')
plt.xlabel('Date',fontsize=14)
plt.xlabel('Temp',fontsize=14)
# Out:
# Text(0.5, 0, 'Temp')

# %%
#Nhiệt độ có xu hướng giảm từ tháng 5 và bắt đầu tăng trở lại vào tháng 9.
#3 tháng đầu năm có nhiệt độ trung bình cao nhất.

# %% [markdown]
# Tổng kết
# Qua bài thực hành này, chúng ta đã biết cách trực quan hóa dữ liệu nhiệt độ bằng một số biểu đồ. Chúng ta cũng biết cách sử dụng thư viện Matplotlib để vẽ biểu đồ dựa trên mục tiêu, dữ liệu và đưa ra một số thông tin dựa trên trực quan hóa dữ liệu.#
